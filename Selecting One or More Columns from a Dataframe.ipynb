# %%
import pandas as pd

# %%
Df=pd.read_csv(r"/content/youtube_4k_channels_cleaned.csv")
Df
# Out:
#       Global Rank                Channel ID                   Channel Name  \
# 0               1  UCX6OQ3DkcsbYNE6H8uQQuVA                        MrBeast
# 1               2  UCq-Fj5jknLsUf-MWSy4_brA                       T-Series
# 2               3  UCpEhnqL0y41EpW2TvWAHD7Q                      SET India
# 3               4  UCvlE5gTbOvjiolFlEm-c_Ow                  Vlad and Niki
# 4               5  UCk8GzjMOrta8yxDcKfylJYw              ✿ Kids Diana Show
# ...           ...                       ...                            ...
# 3959         3960  UCfp-vHLwJjuxcn47hBCfa0w  Anatolian Arabesk Lab - Topic
# 3960         3961  UCQeiGH0k_gwOUpVfeQnRwkA       The Second Voice - Topic
# 3961         3962  UCVieVPiy6vUHzV0fMoAS9ew                     Paramount+
# 3962         3963  UCeAVhQQ4AkhtenvViPwLiXA                Release - Topic
# 3963         3964  UC3nBSi6NwVKRLy29WfatJUw                     Paramount+
#
#       Subscribers   Total Views  Total Videos  Country  \
# ...

# %% [markdown]
# # 1.Selecting one column
#     1.1 Syntax 1

# %%
# select a column with [] (preferred way to select a column)
Df["Channel Name"]
# Out:
# 0                             MrBeast
# 1                            T-Series
# 2                           SET India
# 3                       Vlad and Niki
# 4                   ✿ Kids Diana Show
#                     ...
# 3959    Anatolian Arabesk Lab - Topic
# 3960         The Second Voice - Topic
# 3961                       Paramount+
# 3962                  Release - Topic
# 3963                       Paramount+
# Name: Channel Name, Length: 3964, dtype: object

# %%
# check out the data type of a column
type(Df["Channel Name"])
# Out:
# pandas.core.series.Series

# %%
# series
Df["Channel Name"].index
Df["Channel Name"].head()
# Out:
# 0              MrBeast
# 1             T-Series
# 2            SET India
# 3        Vlad and Niki
# 4    ✿ Kids Diana Show
# Name: Channel Name, dtype: object

# %% [markdown]
# # 1.2 Syntax 2

# %%
# select a column with
Df.Country
# Out:
# 0            US
# 1            IN
# 2            IN
# 3            US
# 4            US
#          ...
# 3959    Unknown
# 3960    Unknown
# 3961    Unknown
# 3962    Unknown
# 3963    Unknown
# Name: Country, Length: 3964, dtype: object

# %%
# selext a column with . (pitfalls)
# Df.Channel Name
# It raises the error

# %%
# select the same column using []
Df["Channel Name"]
# Out:
# 0                             MrBeast
# 1                            T-Series
# 2                           SET India
# 3                       Vlad and Niki
# 4                   ✿ Kids Diana Show
#                     ...
# 3959    Anatolian Arabesk Lab - Topic
# 3960         The Second Voice - Topic
# 3961                       Paramount+
# 3962                  Release - Topic
# 3963                       Paramount+
# Name: Channel Name, Length: 3964, dtype: object

# %% [markdown]
# # 1.Selecting two or more columns

# %%
# select 2 columns using [[]]
Df[["Channel Name","Country"]]
# Out:
#                        Channel Name  Country
# 0                           MrBeast       US
# 1                          T-Series       IN
# 2                         SET India       IN
# 3                     Vlad and Niki       US
# 4                 ✿ Kids Diana Show       US
# ...                             ...      ...
# 3959  Anatolian Arabesk Lab - Topic  Unknown
# 3960       The Second Voice - Topic  Unknown
# 3961                     Paramount+  Unknown
# 3962                Release - Topic  Unknown
# 3963                     Paramount+  Unknown
#
# [3964 rows x 2 columns]

# %%
type(Df[["Channel Name","Country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# select 2 or more columns using [[]]
Df[["Global Rank","Channel ID",	"Channel Name",	"Subscribers",	"Total Views",	"Total Videos",	"Country",	"Description"]]
# Out:
#       Global Rank                Channel ID                   Channel Name  \
# 0               1  UCX6OQ3DkcsbYNE6H8uQQuVA                        MrBeast
# 1               2  UCq-Fj5jknLsUf-MWSy4_brA                       T-Series
# 2               3  UCpEhnqL0y41EpW2TvWAHD7Q                      SET India
# 3               4  UCvlE5gTbOvjiolFlEm-c_Ow                  Vlad and Niki
# 4               5  UCk8GzjMOrta8yxDcKfylJYw              ✿ Kids Diana Show
# ...           ...                       ...                            ...
# 3959         3960  UCfp-vHLwJjuxcn47hBCfa0w  Anatolian Arabesk Lab - Topic
# 3960         3961  UCQeiGH0k_gwOUpVfeQnRwkA       The Second Voice - Topic
# 3961         3962  UCVieVPiy6vUHzV0fMoAS9ew                     Paramount+
# 3962         3963  UCeAVhQQ4AkhtenvViPwLiXA                Release - Topic
# 3963         3964  UC3nBSi6NwVKRLy29WfatJUw                     Paramount+
#
#       Subscribers   Total Views  Total Videos  Country  \
# ...

# %%
# we can't select 2 or more columns with the "."
# Df.Country,Channel ID
