# %%
import pandas as pd

# %%
Df = pd.read_csv("/content/youtube_4k_channels_cleaned.csv")
Df
# Out:
#       Global Rank                Channel ID                   Channel Name  \
# 0               1  UCX6OQ3DkcsbYNE6H8uQQuVA                        MrBeast
# 1               2  UCq-Fj5jknLsUf-MWSy4_brA                       T-Series
# 2               3  UCpEhnqL0y41EpW2TvWAHD7Q                      SET India
# 3               4  UCvlE5gTbOvjiolFlEm-c_Ow                  Vlad and Niki
# 4               5  UCk8GzjMOrta8yxDcKfylJYw              ✿ Kids Diana Show
# ...           ...                       ...                            ...
# 3959         3960  UCfp-vHLwJjuxcn47hBCfa0w  Anatolian Arabesk Lab - Topic
# 3960         3961  UCQeiGH0k_gwOUpVfeQnRwkA       The Second Voice - Topic
# 3961         3962  UCVieVPiy6vUHzV0fMoAS9ew                     Paramount+
# 3962         3963  UCeAVhQQ4AkhtenvViPwLiXA                Release - Topic
# 3963         3964  UC3nBSi6NwVKRLy29WfatJUw                     Paramount+
#
#       Subscribers   Total Views  Total Videos  Country  \
# 0       474000000  1.160060e+11           956       US
# 1       311000000  3.356510e+11         25757       IN
# 2       188000000  1.871860e+11        168366       IN
# 3       149000000  1.201140e+11          1005       US
# 4       138000000  1.235460e+11          1589       US
# ...           ...           ...           ...      ...
# 3959            4  2.331839e+06            13  Unknown
# 3960            2  2.438575e+06             4  Unknown
# 3961            1  2.021232e+08        374138  Unknown
# 3962            0  4.206000e+04             1  Unknown
# 3963            0  3.268923e+08        541883  Unknown
#
#                                             Description  Views per Subscriber  \
# 0     SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...          2.447400e+02
# 1     Music can change the world". T-Series is India...          1.079260e+03
# 2     Sony Entertainment Television is one of the le...          9.956700e+02
# 3     “Vlad & Niki” is the global preschool phenomen...          8.061300e+02
# 4     Welcome to Diana and Roma world - where Diana,...          8.952600e+02
# ...                                                 ...                   ...
# 3959                                                NaN          5.829598e+05
# 3960                                                NaN          1.219288e+06
# 3961                                                NaN          2.021232e+08
# 3962                                                NaN                   NaN
# 3963                                                NaN                   NaN
#
#       Views per Video  Subscribers (M)  Views (B)     Tier
# 0         121344833.0            474.0    116.006  🔴 100M+
# 1          13031434.0            311.0    335.651  🔴 100M+
# 2           1111778.0            188.0    187.186  🔴 100M+
# 3         119516120.0            149.0    120.114  🔴 100M+
# 4          77751069.0            138.0    123.546  🔴 100M+
# ...               ...              ...        ...      ...
# 3959         179372.0              0.0      0.002    🔵 <1M
# 3960         609644.0              0.0      0.002    🔵 <1M
# 3961            540.0              0.0      0.202    🔵 <1M
# 3962          42060.0              0.0      0.000    🔵 <1M
# 3963            603.0              0.0      0.327    🔵 <1M
#
# [3964 rows x 13 columns]

# %%
# show first 5 rows in a dataframe
Df.head()
# Out:
#    Global Rank                Channel ID       Channel Name  Subscribers  \
# 0            1  UCX6OQ3DkcsbYNE6H8uQQuVA            MrBeast    474000000
# 1            2  UCq-Fj5jknLsUf-MWSy4_brA           T-Series    311000000
# 2            3  UCpEhnqL0y41EpW2TvWAHD7Q          SET India    188000000
# 3            4  UCvlE5gTbOvjiolFlEm-c_Ow      Vlad and Niki    149000000
# 4            5  UCk8GzjMOrta8yxDcKfylJYw  ✿ Kids Diana Show    138000000
#
#     Total Views  Total Videos Country  \
# 0  1.160060e+11           956      US
# 1  3.356510e+11         25757      IN
# 2  1.871860e+11        168366      IN
# 3  1.201140e+11          1005      US
# 4  1.235460e+11          1589      US
#
#                                          Description  Views per Subscriber  \
# 0  SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...                244.74
# 1  Music can change the world". T-Series is India...               1079.26
# 2  Sony Entertainment Television is one of the le...                995.67
# 3  “Vlad & Niki” is the global preschool phenomen...                806.13
# 4  Welcome to Diana and Roma world - where Diana,...                895.26
#
#    Views per Video  Subscribers (M)  Views (B)     Tier
# 0      121344833.0            474.0    116.006  🔴 100M+
# 1       13031434.0            311.0    335.651  🔴 100M+
# 2        1111778.0            188.0    187.186  🔴 100M+
# 3      119516120.0            149.0    120.114  🔴 100M+
# 4       77751069.0            138.0    123.546  🔴 100M+

# %%
#show last 5 rows in a dataframe
Df.tail()
# Out:
#       Global Rank                Channel ID                   Channel Name  \
# 3959         3960  UCfp-vHLwJjuxcn47hBCfa0w  Anatolian Arabesk Lab - Topic
# 3960         3961  UCQeiGH0k_gwOUpVfeQnRwkA       The Second Voice - Topic
# 3961         3962  UCVieVPiy6vUHzV0fMoAS9ew                     Paramount+
# 3962         3963  UCeAVhQQ4AkhtenvViPwLiXA                Release - Topic
# 3963         3964  UC3nBSi6NwVKRLy29WfatJUw                     Paramount+
#
#       Subscribers  Total Views  Total Videos  Country Description  \
# 3959            4    2331839.0            13  Unknown         NaN
# 3960            2    2438575.0             4  Unknown         NaN
# 3961            1  202123178.0        374138  Unknown         NaN
# 3962            0      42060.0             1  Unknown         NaN
# 3963            0  326892269.0        541883  Unknown         NaN
#
#       Views per Subscriber  Views per Video  Subscribers (M)  Views (B)   Tier
# 3959          5.829598e+05         179372.0              0.0      0.002  🔵 <1M
# 3960          1.219288e+06         609644.0              0.0      0.002  🔵 <1M
# 3961          2.021232e+08            540.0              0.0      0.202  🔵 <1M
# 3962                   NaN          42060.0              0.0      0.000  🔵 <1M
# 3963                   NaN            603.0              0.0      0.327  🔵 <1M

# %%
#show last n rows in a dataframe
Df.head(10)
# Out:
#    Global Rank                Channel ID       Channel Name  Subscribers  \
# 0            1  UCX6OQ3DkcsbYNE6H8uQQuVA            MrBeast    474000000
# 1            2  UCq-Fj5jknLsUf-MWSy4_brA           T-Series    311000000
# 2            3  UCpEhnqL0y41EpW2TvWAHD7Q          SET India    188000000
# 3            4  UCvlE5gTbOvjiolFlEm-c_Ow      Vlad and Niki    149000000
# 4            5  UCk8GzjMOrta8yxDcKfylJYw  ✿ Kids Diana Show    138000000
# 5            6  UCFFbwnve3yF62-tVXkTyHqg  Zee Music Company    122000000
# 6            7  UCJ5v_MCY6GNUBTO8-D3XoAg                WWE    112000000
# 7            8  UC-lHJZR3Gqxm24_Vd_AJ5Yw          PewDiePie    110000000
# 8            9  UCOmHUn--16B90oW2L6FRR3A          BLACKPINK    100000000
# 9           10  UCLkAepWjdylmXSltofFvsYQ          BANGTANTV     83300000
#
#     Total Views  Total Videos  Country  \
# 0  1.160060e+11           956       US
# 1  3.356510e+11         25757       IN
# 2  1.871860e+11        168366       IN
# 3  1.201140e+11          1005       US
# 4  1.235460e+11          1589       US
# 5  8.696823e+10         15963       IN
# 6  1.029290e+11         92131  Unknown
# 7  2.948522e+10          4660       JP
# 8  4.175643e+10           666       KR
# 9  2.717666e+10          2984  Unknown
#
#                                          Description  Views per Subscriber  \
# 0  SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...                244.74
# 1  Music can change the world". T-Series is India...               1079.26
# 2  Sony Entertainment Television is one of the le...                995.67
# 3  “Vlad & Niki” is the global preschool phenomen...                806.13
# 4  Welcome to Diana and Roma world - where Diana,...                895.26
# 5  Zee Music Company is part of India's leading t...                712.85
# 6  WWE on YouTube is your number one spot to catc...                919.01
# 7                                     I make videos.                268.05
# 8  BLACKPINK Official YouTube Channel 블랙핑크 공식 유튜브...                417.56
# 9  This is the official YouTube channel of BTS. 방...                326.25
#
#    Views per Video  Subscribers (M)  Views (B)       Tier
# 0      121344833.0            474.0    116.006    🔴 100M+
# 1       13031434.0            311.0    335.651    🔴 100M+
# 2        1111778.0            188.0    187.186    🔴 100M+
# 3      119516120.0            149.0    120.114    🔴 100M+
# 4       77751069.0            138.0    123.546    🔴 100M+
# 5        5448113.0            122.0     86.968    🔴 100M+
# 6        1117201.0            112.0    102.929    🔴 100M+
# 7        6327300.0            110.0     29.485    🔴 100M+
# 8       62697348.0            100.0     41.756    🔴 100M+
# 9        9107458.0             83.3     27.177  🟠 50–100M

# %%
# show first n rows in a dataframe
Df.tail(10)
# Out:
#       Global Rank                Channel ID                   Channel Name  \
# 3954         3955  UCKk0HhH1MxdvtlErWBWIELg             TarnAIThai - Topic
# 3955         3956  UC60z0OBnOjkDFJJEJ0VUywQ                Release - Topic
# 3956         3957  UCcIHdFDHz6LjAb_sMp_axFQ                 ARMONİ - Topic
# 3957         3958  UCEH_rDVTdmzzHIVHu_83umA        ilostmyfeelings - Topic
# 3958         3959  UCMnIvt22T-bGvYalgYsKTtA          Furkan Kalkan - Topic
# 3959         3960  UCfp-vHLwJjuxcn47hBCfa0w  Anatolian Arabesk Lab - Topic
# 3960         3961  UCQeiGH0k_gwOUpVfeQnRwkA       The Second Voice - Topic
# 3961         3962  UCVieVPiy6vUHzV0fMoAS9ew                     Paramount+
# 3962         3963  UCeAVhQQ4AkhtenvViPwLiXA                Release - Topic
# 3963         3964  UC3nBSi6NwVKRLy29WfatJUw                     Paramount+
#
#       Subscribers  Total Views  Total Videos  Country  \
# 3954            5      15224.0            48  Unknown
# 3955            5      18364.0             1  Unknown
# 3956            5      13613.0            43  Unknown
# 3957            4      49776.0            16  Unknown
# 3958            4     588138.0            18  Unknown
# 3959            4    2331839.0            13  Unknown
# 3960            2    2438575.0             4  Unknown
# 3961            1  202123178.0        374138  Unknown
# 3962            0      42060.0             1  Unknown
# 3963            0  326892269.0        541883  Unknown
#
#                                             Description  Views per Subscriber  \
# 3954                                                NaN          3.044800e+03
# 3955                                                NaN          3.672800e+03
# 3956                                                NaN          2.722600e+03
# 3957                                                NaN          1.244400e+04
# 3958  🎸 Furkan Kalkan – Psychedelic Anatolian Rock &...          1.470345e+05
# 3959                                                NaN          5.829598e+05
# 3960                                                NaN          1.219288e+06
# 3961                                                NaN          2.021232e+08
# 3962                                                NaN                   NaN
# 3963                                                NaN                   NaN
#
#       Views per Video  Subscribers (M)  Views (B)   Tier
# 3954            317.0              0.0      0.000  🔵 <1M
# 3955          18364.0              0.0      0.000  🔵 <1M
# 3956            317.0              0.0      0.000  🔵 <1M
# 3957           3111.0              0.0      0.000  🔵 <1M
# 3958          32674.0              0.0      0.001  🔵 <1M
# 3959         179372.0              0.0      0.002  🔵 <1M
# 3960         609644.0              0.0      0.002  🔵 <1M
# 3961            540.0              0.0      0.202  🔵 <1M
# 3962          42060.0              0.0      0.000  🔵 <1M
# 3963            603.0              0.0      0.327  🔵 <1M

# %%
# getting access to the shape attribute
Df.shape
# Out:
# (3964, 13)

# %%
#display n rows
pd.set_option("display.max_rows",3964)
Df
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 1 *Attributes*

# %%
# getting access to the shape attribute
Df.shape
# Out:
# (3964, 13)

# %%
#getting access to the index attribute
Df.index
# Out:
# RangeIndex(start=0, stop=3964, step=1)

# %%
#getting access to the column attribute
Df.columns
# Out:
# Index(['Global Rank', 'Channel ID', 'Channel Name', 'Subscribers',
#        'Total Views', 'Total Videos', 'Country', 'Description',
#        'Views per Subscriber', 'Views per Video', 'Subscribers (M)',
#        'Views (B)', 'Tier'],
#       dtype='object')

# %%
# data type of each column
Df.dtypes
# Out:
# Global Rank               int64
# Channel ID               object
# Channel Name             object
# Subscribers               int64
# Total Views             float64
# Total Videos              int64
# Country                  object
# Description              object
# Views per Subscriber    float64
# Views per Video         float64
# Subscribers (M)         float64
# Views (B)               float64
# Tier                     object
# dtype: object

# %% [markdown]
# Object is always any kind of string.

# %% [markdown]
# # 2 Methods

# %%
# To show first 5 rows
Df.head()
# Out:
#    Global Rank                Channel ID       Channel Name  Subscribers  \
# 0            1  UCX6OQ3DkcsbYNE6H8uQQuVA            MrBeast    474000000
# 1            2  UCq-Fj5jknLsUf-MWSy4_brA           T-Series    311000000
# 2            3  UCpEhnqL0y41EpW2TvWAHD7Q          SET India    188000000
# 3            4  UCvlE5gTbOvjiolFlEm-c_Ow      Vlad and Niki    149000000
# 4            5  UCk8GzjMOrta8yxDcKfylJYw  ✿ Kids Diana Show    138000000
#
#     Total Views  Total Videos Country  \
# 0  1.160060e+11           956      US
# 1  3.356510e+11         25757      IN
# 2  1.871860e+11        168366      IN
# 3  1.201140e+11          1005      US
# 4  1.235460e+11          1589      US
#
#                                          Description  Views per Subscriber  \
# 0  SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...                244.74
# 1  Music can change the world". T-Series is India...               1079.26
# 2  Sony Entertainment Television is one of the le...                995.67
# 3  “Vlad & Niki” is the global preschool phenomen...                806.13
# 4  Welcome to Diana and Roma world - where Diana,...                895.26
#
#    Views per Video  Subscribers (M)  Views (B)     Tier
# 0      121344833.0            474.0    116.006  🔴 100M+
# 1       13031434.0            311.0    335.651  🔴 100M+
# 2        1111778.0            188.0    187.186  🔴 100M+
# 3      119516120.0            149.0    120.114  🔴 100M+
# 4       77751069.0            138.0    123.546  🔴 100M+

# %%
# Showing the info of the dataframe
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3964 entries, 0 to 3963
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Global Rank           3964 non-null   int64
#  1   Channel ID            3964 non-null   object
#  2   Channel Name          3964 non-null   object
#  3   Subscribers           3964 non-null   int64
#  4   Total Views           3964 non-null   float64
#  5   Total Videos          3964 non-null   int64
#  6   Country               3964 non-null   object
#  7   Description           3457 non-null   object
#  8   Views per Subscriber  3962 non-null   float64
#  9   Views per Video       3963 non-null   float64
#  10  Subscribers (M)       3964 non-null   float64
#  11  Views (B)             3964 non-null   float64
#  12  Tier                  3964 non-null   object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 402.7+ KB

# %%
# describing basic statistics of the dataframe
Df.describe()
# Out:
#        Global Rank   Subscribers   Total Views   Total Videos  \
# count  3964.000000  3.964000e+03  3.964000e+03    3964.000000
# mean   1982.500000  2.258728e+06  1.220083e+09    2121.621594
# std    1144.452562  1.192432e+07  7.981924e+09   14379.953625
# min       1.000000  0.000000e+00  0.000000e+00       0.000000
# 25%     991.750000  6.507500e+04  2.591287e+07     139.750000
# 50%    1982.500000  3.430000e+05  1.353160e+08     610.500000
# 75%    2973.250000  1.330000e+06  5.888938e+08    1843.500000
# max    3964.000000  4.740000e+08  3.356510e+11  541883.000000
#
#        Views per Subscriber  Views per Video  Subscribers (M)    Views (B)
# count          3.962000e+03     3.963000e+03      3964.000000  3964.000000
# mean           5.689710e+04     1.462053e+06         2.258671     1.220084
# std            3.212099e+06     8.491853e+06        11.924335     7.981923
# min            0.000000e+00     0.000000e+00         0.000000     0.000000
# 25%            2.235525e+02     7.039800e+04         0.067500     0.026000
# 50%            3.888800e+02     2.172010e+05         0.340000     0.135000
# 75%            7.352575e+02     6.970525e+05         1.330000     0.589000
# max            2.021232e+08     2.320543e+08       474.000000   335.651000

# %% [markdown]
# # 3. Functions

# %%
# obtaining the length of the dataframe(number of rows)
len(Df)
# Out:
# 3964

# %%
# Obtaining the highest index of the dataframe
max(Df.index)
# Out:
# 3963

# %%
# Obatining the lowest index of the dataframe
min(Df.index)
# Out:
# 0

# %%
# obtaining the data type
type(Df)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the datset
round(Df,2).head(5)
# Out:
#    Global Rank                Channel ID       Channel Name  Subscribers  \
# 0            1  UCX6OQ3DkcsbYNE6H8uQQuVA            MrBeast    474000000
# 1            2  UCq-Fj5jknLsUf-MWSy4_brA           T-Series    311000000
# 2            3  UCpEhnqL0y41EpW2TvWAHD7Q          SET India    188000000
# 3            4  UCvlE5gTbOvjiolFlEm-c_Ow      Vlad and Niki    149000000
# 4            5  UCk8GzjMOrta8yxDcKfylJYw  ✿ Kids Diana Show    138000000
#
#     Total Views  Total Videos Country  \
# 0  1.160060e+11           956      US
# 1  3.356510e+11         25757      IN
# 2  1.871860e+11        168366      IN
# 3  1.201140e+11          1005      US
# 4  1.235460e+11          1589      US
#
#                                          Description  Views per Subscriber  \
# 0  SUBSCRIBE FOR A COOKIE! New MrBeast or MrBeast...                244.74
# 1  Music can change the world". T-Series is India...               1079.26
# 2  Sony Entertainment Television is one of the le...                995.67
# 3  “Vlad & Niki” is the global preschool phenomen...                806.13
# 4  Welcome to Diana and Roma world - where Diana,...                895.26
#
#    Views per Video  Subscribers (M)  Views (B)     Tier
# 0      121344833.0            474.0     116.01  🔴 100M+
# 1       13031434.0            311.0     335.65  🔴 100M+
# 2        1111778.0            188.0     187.19  🔴 100M+
# 3      119516120.0            149.0     120.11  🔴 100M+
# 4       77751069.0            138.0     123.55  🔴 100M+
